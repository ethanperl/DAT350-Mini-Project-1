# %%
import pandas as pd
import matplotlib.pyplot as plot

sleepDF = pd.read_csv("sleep_survey.csv")
sleepDF.head
# Out:
# <bound method NDFrame.head of           Timestamp     class athlete?            crs_hrs comfort? bed_size  \
# 0   1/23/2024 21:02    Senior      Yes                 13      Yes    Queen
# 1   1/23/2024 21:10    Junior      Yes                 14      Yes  Twin XL
# 2   1/23/2024 21:11  Sophmore      Yes                 13      Yes  Twin XL
# 3   1/23/2024 21:12   Senior+      Yes                 13      Yes  Twin XL
# 4   1/23/2024 21:14  Sophmore      Yes                 12      Yes  Twin XL
# 5   1/23/2024 21:28  Freshman      Yes                 12      Yes  Twin XL
# 6   1/23/2024 21:35    Junior      Yes                 13      Yes  Twin XL
# 7   1/23/2024 21:45   Senior+       No                 15      Yes     Full
# 8   1/23/2024 21:57    Senior       No                 15      Yes  Twin XL
# 9   1/23/2024 22:19  Freshman      Yes                 13      Yes  Twin XL
# 10   1/24/2024 9:32    Senior      Yes                 12      Yes  Twin XL
# 11  1/24/2024 10:49    Senior       No                 12       No  Twin XL
# 12  1/24/2024 12:13    Junior      Yes                 15      Yes  Twin XL
# 13  1/24/2024 12:41    Junior      Yes                 14      Yes  Twin XL
# 14  1/24/2024 13:32    Junior      Yes                 17       No  Twin XL
# 15  1/24/2024 14:12    Junior      Yes                 13      Yes  Twin XL
# 16  1/24/2024 14:13  Sophmore      Yes                 16      Yes  Twin XL
# 17  1/24/2024 14:28  Sophmore      Yes                 15      Yes  Twin XL
# 18  1/24/2024 14:31    Junior      Yes                 17      Yes  Twin XL
# 19  1/24/2024 14:31    Senior      Yes                 17      Yes    Queen
# 20  1/24/2024 15:08    Junior      Yes                 12      Yes  Twin XL
# 21  1/24/2024 15:25    Junior      Yes                 15      Yes    Queen
# 22  1/24/2024 16:16    Senior      Yes                 15      Yes  Twin XL
# 23  1/24/2024 19:34    Junior      Yes                 14      Yes  Twin XL
# 24  1/24/2024 19:41    Junior      Yes                 13      Yes  Twin XL
# 25  1/24/2024 19:43    Junior       No                 17      Yes  Twin XL
# 26  1/24/2024 19:46    Junior      Yes                 17      Yes  Twin XL
# 27  1/24/2024 19:46    Junior      Yes                 16      Yes  Twin XL
# 28  1/24/2024 19:46    Junior      Yes                 17      Yes  Twin XL
# 29  1/24/2024 19:57    Junior      Yes                 13      Yes  Twin XL
# 30  1/24/2024 20:30   Senior+      Yes                 16      Yes     Full
# 31   1/25/2024 6:08    Senior      Yes                 15      Yes    Queen
# 32   1/25/2024 9:01  Freshman      Yes                 15      Yes  Twin XL
# 33   1/25/2024 9:29    Junior       No                 16      Yes    Queen
# 34  1/25/2024 10:44    Senior      Yes                 12      Yes     Full
# 35  1/25/2024 10:46    Junior      Yes                 14      Yes  Twin XL
# 36  1/25/2024 10:46    Senior      Yes                 14      Yes  Twin XL
# 37  1/25/2024 11:27   Senior+       No  Teaching 10 hours      Yes    Queen
# 38  1/25/2024 12:45    Junior      Yes                 12      Yes     King
# 39  1/25/2024 12:45    Senior      Yes                 12      Yes    Queen
# 40  1/25/2024 12:46    Junior      Yes                 12      Yes     Full
# 41  1/25/2024 12:47  Sophmore      Yes                 13      Yes  Twin XL
# 42  1/25/2024 13:41    Junior      Yes                 12      Yes    Queen
# 43  1/25/2024 13:44    Junior      Yes                 16      Yes     Full
# 44  1/25/2024 20:40    Junior       No                 13      Yes  Twin XL
# 45  1/26/2024 19:12    Junior      Yes                 12      Yes  Twin XL
# 46   1/27/2024 8:05  Sophmore      Yes                 14      Yes  Twin XL
# 47   1/27/2024 8:06    Junior      Yes                 16      Yes  Twin XL
# 48   1/27/2024 8:07    Junior      Yes                 16      Yes  Twin XL
# 49   1/27/2024 8:10   Senior+      Yes                 12      Yes    Queen
#
#     num_rmates hrs_sleep hot_cold morn_night noise_silence sleep_variety  \
# 0            4        6+     Cold      Night         Noise         Heavy
# 1            4        6+     Cold      Night       Silence        Medium
# 2            1        6+     Cold      Night         Noise         Heavy
# 3            3        6+     Cold      Night         Noise         Light
# 4            1        6+     Cold      Night         Noise        Medium
# 5            1        8+     Cold    Morning       Silence         Heavy
# 6            1        6+     Cold      Night       Silence         Heavy
# 7            4        6+     Cold    Morning       Silence        Medium
# 8            3        6+     Cold    Morning       Silence        Medium
# 9            1        6+     Cold      Night       Silence        Medium
# 10           3        8+      Hot      Night       Silence         Heavy
# 11           0        4+     Cold    Morning         Noise        Medium
# 12           3        6+     Cold      Night         Noise         Heavy
# 13           0        6+     Cold      Night       Silence        Medium
# 14           1        6+     Cold      Night       Silence         Heavy
# 15           1        6+     Cold      Night         Noise         Heavy
# 16           1        6+     Cold      Night       Silence         Light
# 17           1        6+     Cold      Night       Silence         Light
# 18           4        6+     Cold      Night       Silence        Medium
# 19           4        6+     Cold    Morning       Silence        Medium
# 20           1        8+     Cold    Morning       Silence         Light
# 21           2        6+     Cold      Night       Silence         Light
# 22           1        6+     Cold      Night       Silence        Medium
# 23           1        8+     Cold    Morning       Silence         Light
# 24           0        8+     Cold      Night       Silence        Medium
# 25           4        6+     Cold      Night       Silence        Medium
# 26           1        6+     Cold    Morning       Silence        Medium
# 27           1        6+     Cold      Night       Silence        Medium
# 28           1        6+     Cold    Morning       Silence        Medium
# 29           1        6+     Cold    Morning       Silence         Heavy
# 30           3        8+     Cold      Night       Silence        Medium
# 31           0        6+     Cold    Morning       Silence        Medium
# 32           1        6+     Cold      Night       Silence        Medium
# 33           0        4+     Cold      Night         Noise         Light
# 34           1        6+     Cold      Night         Noise         Light
# 35           1        6+     Cold    Morning       Silence        Medium
# 36           3        6+     Cold      Night       Silence         Heavy
# 37           0        6+     Cold      Night       Silence        Medium
# 38           2        8+     Cold    Morning         Noise         Light
# 39           4        8+     Cold    Morning         Noise         Light
# 40           4        8+     Cold      Night         Noise         Heavy
# 41           1        6+     Cold      Night         Noise        Medium
# 42           4        8+     Cold    Morning         Noise         Heavy
# 43           2        8+     Cold    Morning         Noise        Medium
# 44           1        6+     Cold    Morning       Silence        Medium
# 45           3        6+     Cold    Morning       Silence        Medium
# 46           1        8+     Cold    Morning       Silence        Medium
# 47           1        6+     Cold    Morning       Silence        Medium
# 48           1        6+     Cold      Night       Silence        Medium
# 49           0        6+     Cold    Morning         Noise        Medium
#
#                           bed_times sleep_quality           sleep_posn  \
# 0                      11 pm, 12 am          Good                 Back
# 1                          12:00 AM          Good                 Back
# 2               10 pm, 11 pm, 12 am          Good        Side, Stomach
# 3                11 pm, 12 am, 1 am      Mediocre  Back, Side, Stomach
# 4                           3:00 AM          Poor                 Side
# 5   8 pm, 9 pm, 10 pm, 11 pm, 12 am         Great  Back, Side, Stomach
# 6                        1 am, 2 am      Mediocre                 Side
# 7               10 pm, 11 pm, 12 am          Good           Back, Side
# 8                      11 pm, 12 am          Good                 Side
# 9               10 pm, 11 pm, 12 am          Poor           Back, Side
# 10                      12 am, 1 am          Good  Back, Side, Stomach
# 11                 1 am, 2 am, 3 am          Poor           Back, Side
# 12               11 pm, 12 am, 1 am      Mediocre                 Side
# 13                12 am, 1 am, 2 am          Good                 Back
# 14        10 pm, 11 pm, 12 am, 1 am      Mediocre           Back, Side
# 15               11 pm, 12 am, 1 am          Good  Back, Side, Stomach
# 16               9 pm, 10 pm, 11 pm          Good           Back, Side
# 17                     10 pm, 11 pm          Poor           Back, Side
# 18                     11 pm, 12 am          Good           Back, Side
# 19                     10 pm, 11 pm          Poor  Back, Side, Stomach
# 20                      9 pm, 10 pm          Good                 Side
# 21                     11 pm, 12 am          Poor              Stomach
# 22               11 pm, 12 am, 1 am      Mediocre                 Side
# 23                      9 pm, 10 pm          Good                 Back
# 24               11 pm, 12 am, 1 am         Great        Side, Stomach
# 25              10 pm, 11 pm, 12 am      Mediocre           Back, Side
# 26                      9 pm, 10 pm          Good                 Back
# 27                         11:00 PM          Good                 Side
# 28                     10 pm, 11 pm          Good                 Side
# 29                         10:00 PM          Good        Side, Stomach
# 30                         10:00 PM      Mediocre              Stomach
# 31                      9 pm, 10 pm      Mediocre  Back, Side, Stomach
# 32                     11 pm, 12 am          Good                 Side
# 33                 1 am, 2 am, 3 am          Good        Side, Stomach
# 34                         12:00 AM      Mediocre              Stomach
# 35        10 pm, 11 pm, 12 am, 1 am          Good                 Side
# 36                         12:00 AM          Good        Side, Stomach
# 37                       1 am, 2 am          Good                 Side
# 38                     10 pm, 11 pm      Mediocre        Side, Stomach
# 39                         10:00 PM          Good                 Side
# 40                         12:00 AM         Great                 Back
# 41              10 pm, 11 pm, 12 am      Mediocre                 Side
# 42                         11:00 PM          Good        Side, Stomach
# 43                     10 pm, 11 pm      Mediocre           Back, Side
# 44                12 am, 1 am, 2 am      Mediocre                 Side
# 45                         10:00 PM         Great           Back, Side
# 46                     10 pm, 11 pm         Great        Side, Stomach
# 47               9 pm, 10 pm, 11 pm          Good              Stomach
# 48              10 pm, 11 pm, 12 am          Good                 Side
# 49              10 pm, 11 pm, 12 am          Good                 Back
#
#    refreshed?                                          why_sleep
# 0         Yes                                                NaN
# 1         Yes                                                NaN
# 2         Yes                                                NaN
# 3          No                                                NaN
# 4          No                                                NaN
# 28        6+     Cold    Morning       Silence        Medium
# 29        6+     Cold    Morning       Silence         Heavy
# 30        8+     Cold      Night       Silence        Medium
# 31        6+     Cold    Morning       Silence        Medium
# 32        6+     Cold      Night       Silence        Medium
# 33        4+     Cold      Night         Noise         Light
# 34        6+     Cold      Night         Noise         Light
# 35        6+     Cold    Morning       Silence        Medium
# 36        6+     Cold      Night       Silence         Heavy
# 37        6+     Cold      Night       Silence        Medium
# 38        8+     Cold    Morning         Noise         Light
# 39        8+     Cold    Morning         Noise         Light
# 40        8+     Cold      Night         Noise         Heavy
# 41        6+     Cold      Night         Noise        Medium
# 42        8+     Cold    Morning         Noise         Heavy
# 43        8+     Cold    Morning         Noise        Medium
# 44        6+     Cold    Morning       Silence        Medium
# 45        6+     Cold    Morning       Silence        Medium
# 46        8+     Cold    Morning       Silence        Medium
# 47        6+     Cold    Morning       Silence        Medium
# 48        6+     Cold      Night       Silence        Medium
# 49        6+     Cold    Morning         Noise        Medium
#
#                           bed_times sleep_quality           sleep_posn  \
# 5   8 pm, 9 pm, 10 pm, 11 pm, 12 am         Great  Back, Side, Stomach
# 6                        1 am, 2 am      Mediocre                 Side
# 7               10 pm, 11 pm, 12 am          Good           Back, Side
# 8                      11 pm, 12 am          Good                 Side
# 9               10 pm, 11 pm, 12 am          Poor           Back, Side
# 10                      12 am, 1 am          Good  Back, Side, Stomach
# 11                 1 am, 2 am, 3 am          Poor           Back, Side
# 12               11 pm, 12 am, 1 am      Mediocre                 Side
# 13                12 am, 1 am, 2 am          Good                 Back
# 14        10 pm, 11 pm, 12 am, 1 am      Mediocre           Back, Side
# 15               11 pm, 12 am, 1 am          Good  Back, Side, Stomach
# 16               9 pm, 10 pm, 11 pm          Good           Back, Side
# 17                     10 pm, 11 pm          Poor           Back, Side
# 18                     11 pm, 12 am          Good           Back, Side
# 19                     10 pm, 11 pm          Poor  Back, Side, Stomach
# 20                      9 pm, 10 pm          Good                 Side
# 21                     11 pm, 12 am          Poor              Stomach
# 22               11 pm, 12 am, 1 am      Mediocre                 Side
# 23                      9 pm, 10 pm          Good                 Back
# 24               11 pm, 12 am, 1 am         Great        Side, Stomach
# 25              10 pm, 11 pm, 12 am      Mediocre           Back, Side
# 26                      9 pm, 10 pm          Good                 Back
# 27                         11:00 PM          Good                 Side
# 28                     10 pm, 11 pm          Good                 Side
# 29                         10:00 PM          Good        Side, Stomach
# 30                         10:00 PM      Mediocre              Stomach
# 31                      9 pm, 10 pm      Mediocre  Back, Side, Stomach
# 32                     11 pm, 12 am          Good                 Side
# 33                 1 am, 2 am, 3 am          Good        Side, Stomach
# 34                         12:00 AM      Mediocre              Stomach
# 35        10 pm, 11 pm, 12 am, 1 am          Good                 Side
# 36                         12:00 AM          Good        Side, Stomach
# 37                       1 am, 2 am          Good                 Side
# 38                     10 pm, 11 pm      Mediocre        Side, Stomach
# 39                         10:00 PM          Good                 Side
# 40                         12:00 AM         Great                 Back
# 41              10 pm, 11 pm, 12 am      Mediocre                 Side
# 42                         11:00 PM          Good        Side, Stomach
# 43                     10 pm, 11 pm      Mediocre           Back, Side
# 44                12 am, 1 am, 2 am      Mediocre                 Side
# 45                         10:00 PM         Great           Back, Side
# 46                     10 pm, 11 pm         Great        Side, Stomach
# 47               9 pm, 10 pm, 11 pm          Good              Stomach
# 48              10 pm, 11 pm, 12 am          Good                 Side
# 49              10 pm, 11 pm, 12 am          Good                 Back
#
#    refreshed?                                          why_sleep
# 5         Yes                               Athletic Performance
# 6          No  Physical Health, Academic Performance, Athleti...
# 7         Yes  Physical Health, Mental Health, Academic Perfo...
# 8         Yes                     Physical Health, Mental Health
# 9          No  Physical Health, Mental Health, Academic Perfo...
# 10        Yes                     Physical Health, Mental Health
# 11         No                     Physical Health, Mental Health
# 12        Yes                     Physical Health, Mental Health
# 13        Yes                     Physical Health, Mental Health
# 14         No  Physical Health, Mental Health, Academic Perfo...
# 15        Yes  Mental Health, Academic Performance, An escape...
# 16        Yes  Physical Health, Mental Health, Academic Perfo...
# 17         No  Physical Health, Mental Health, Athletic Perfo...
# 18        Yes  Physical Health, Mental Health, Academic Perfo...
# 19         No  Physical Health, Mental Health, Academic Perfo...
# 20        Yes  Physical Health, Mental Health, Academic Perfo...
# 21         No  Physical Health, Mental Health, Academic Perfo...
# 22         No  Physical Health, Mental Health, Athletic Perfo...
# 23        Yes  Physical Health, Mental Health, Academic Perfo...
# 24        Yes  Physical Health, Mental Health, Academic Perfo...
# 25         No  Physical Health, Mental Health, Academic Perfo...
# 26        Yes  Physical Health, Mental Health, Academic Perfo...
# 27         No  Physical Health, Mental Health, Academic Perfo...
# 28        Yes  Physical Health, Mental Health, Academic Perfo...
# 29        Yes  Physical Health, Mental Health, Academic Perfo...
# 30        Yes  Physical Health, Mental Health, Academic Perfo...
# 31        Yes              Physical Health, Athletic Performance
# 32        Yes  Physical Health, Mental Health, Academic Perfo...
# 33         No  Physical Health, Mental Health, Academic Perfo...
# 34         No  Physical Health, Mental Health, Academic Perfo...
# 35        Yes  Physical Health, Mental Health, Academic Perfo...
# 36        Yes  Physical Health, Mental Health, Academic Perfo...
# 37        Yes  Physical Health, Mental Health, Academic Perfo...
# 38         No  Physical Health, Mental Health, Academic Perfo...
# 39        Yes  Physical Health, Mental Health, Athletic Perfo...
# 40        Yes  Physical Health, Mental Health, Athletic Perfo...
# 41         No  Physical Health, Academic Performance, Athleti...
# 42        Yes  Physical Health, Mental Health, Academic Perfo...
# 43         No  Physical Health, Mental Health, Academic Perfo...
# 44         No                     Physical Health, Mental Health
# 45        Yes              Physical Health, Athletic Performance
# 46        Yes  Physical Health, Academic Performance, Athleti...
# 47        Yes  Physical Health, Mental Health, Academic Perfo...
# 48         No  Physical Health, Mental Health, Academic Perfo...
# 49        Yes  Physical Health, Mental Health, Academic Perfo...  >

# %% [markdown]
# Questions about "Who": class, athlete?, crs_hours

# %%
## class percentages
class_group = filtSleepDF.groupby("class").size()
class_group
# Out:
# class
# Freshman     3
# Junior      25
# Senior       9
# Senior+      4
# Sophmore     4
# dtype: int64

# %%
plot.pie(class_group, labels=class_group.index, autopct='%1.1f%%')

plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## Athlete percentages
athlete_group = filtSleepDF.groupby("athlete?").size()
athlete_group
# Out:
# athlete?
# No      7
# Yes    38
# dtype: int64

# %%
labels = ['Non-Athlete', 'Athlete']
plot.pie(athlete_group, labels=labels, autopct='%1.1f%%')

plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## Group by course hours
crs_hrs_group = filtSleepDF.groupby("crs_hrs").size()
crs_hrs_group
# Out:
# crs_hrs
# 12                   11
# 13                    7
# 14                    5
# 15                    8
# 16                    7
# 17                    6
# Teaching 10 hours     1
# dtype: int64

# %%
plot.pie(crs_hrs_group, labels=crs_hrs_group.index, autopct='%1.1f%%')

plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Questions about "What": Comfort, sleep_posn

# %%
comfort_group = filtSleepDF.groupby("comfort?").size()
comfort_group
# Out:
# comfort?
# No      2
# Yes    43
# dtype: int64

# %%
## group by comfort
labels = ["Not Comfy", "Comfy"]
plot.pie(comfort_group, labels=labels, autopct='%1.1f%%')

plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sleep_posn_group = filtSleepDF.groupby("sleep_posn").size()
sleep_posn_group
# Out:
# sleep_posn
# Back                    5
# Back, Side             10
# Back, Side, Stomach     5
# Side                   14
# Side, Stomach           7
# Stomach                 4
# dtype: int64

# %%
plot.pie(sleep_posn_group, labels=sleep_posn_group.index, autopct='%1.1f%%')
plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Questions about "When": hrs_sleep, morn_night, bedtimes

# %%
## group by hours of sleep
hrs_sleep_group = filtSleepDF.groupby("hrs_sleep").size()
## chatgpt begin
categories = ['4+', '6+', '8+', '10+']
hrs_sleep_group = hrs_sleep_group.reindex(categories, fill_value=0)
##chatgpt end
hrs_sleep_group
# Out:
# hrs_sleep
# 4+      2
# 6+     31
# 8+     12
# 10+     0
# dtype: int64

# %% [markdown]
# ChatGPT propmt: The indexs are 4+, 6+, 8+, and 10+, but since none answered 10+ it is not showing up, how do i go about adding it to the pie chart
#
# ChatGPT answer: if you want to ensure that all categories, including those with zero counts, are represented in your hrs_sleep_group series when creating a pie chart, you can use the reindex() function to explicitly include the missing categories and assign them zero counts.
#
# Code snippets are marked in the cell above

# %%
plot.pie(hrs_sleep_group, labels=hrs_sleep_group.index, autopct='%1.1f%%')
plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## group by morning or night person
morn_night_group = filtSleepDF.groupby("morn_night").size()
morn_night_group
# Out:
# morn_night
# Morning    21
# Night      24
# dtype: int64

# %%
labels = ["Morning Person", "Night Person"]
plot.pie(morn_night_group, labels=labels, autopct='%1.1f%%')
plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## group by bed time
bed_times_group = filtSleepDF.groupby("bed_times").size()
bed_times_group
# Out:
# bed_times
# 1 am, 2 am                         2
# 1 am, 2 am, 3 am                   2
# 10 pm, 11 pm                       6
# 10 pm, 11 pm, 12 am                6
# 10 pm, 11 pm, 12 am, 1 am          2
# 10:00 PM                           4
# 11 pm, 12 am                       4
# 11 pm, 12 am, 1 am                 4
# 11:00 PM                           2
# 12 am, 1 am                        1
# 12 am, 1 am, 2 am                  2
# 12:00 AM                           3
# 8 pm, 9 pm, 10 pm, 11 pm, 12 am    1
# 9 pm, 10 pm                        4
# 9 pm, 10 pm, 11 pm                 2
# dtype: int64

# %%
count = bed_times_group.sum()
plot.pie(bed_times_group, labels= bed_times_group.index, autopct='%1.1f%%', )

plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Questions about "Where": num_roomates, bed size

# %%
## group by number of roomates
rmt_group = filtSleepDF.groupby("num_rmates").size()
rmt_group
# Out:
# num_rmates
# 0     7
# 1    22
# 2     3
# 3     6
# 4     7
# dtype: int64

# %%
plot.pie(rmt_group, labels=rmt_group.index, autopct='%1.1f%%')
plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
filtSleepDF["num_rmates"].mean()
# Out:
# 1.6444444444444444

# %%
filtSleepDF["num_rmates"].median()
# Out:
# 1.0

# %%
filtSleepDF["num_rmates"].mode()
# Out:
# 0    1
# Name: num_rmates, dtype: int64

# %%
bed_group = filtSleepDF.groupby("bed_size").size()
bed_group
# Out:
# bed_size
# Full        5
# King        1
# Queen       8
# Twin XL    31
# dtype: int64

# %%
plot.pie(bed_group, labels=bed_group.index, autopct='%1.1f%%')
plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Questions about "Why": refreshed?, why_sleep, quality

# %%
## refreshed group
refreshed_group = filtSleepDF.groupby("refreshed?").size()
refreshed_group
# Out:
# refreshed?
# No     17
# Yes    28
# dtype: int64

# %%
labels = ['Not Refreshed', 'Refreshed']
plot.pie(refreshed_group, labels=labels, autopct='%1.1f%%')

plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## why sleep
why_sleep_group = filtSleepDF.groupby("why_sleep").size()
why_sleep_group
# Out:
# why_sleep
# Athletic Performance                                                                                   1
# Mental Health, Academic Performance, An escape from reality                                            1
# Physical Health, Academic Performance, Athletic Performance                                            3
# Physical Health, Athletic Performance                                                                  2
# Physical Health, Mental Health                                                                         6
# Physical Health, Mental Health, Academic Performance                                                   5
# Physical Health, Mental Health, Academic Performance, Athletic Performance                            17
# Physical Health, Mental Health, Academic Performance, Athletic Performance, An escape from reality     6
# Physical Health, Mental Health, Athletic Performance                                                   3
# Physical Health, Mental Health, Athletic Performance, I love it                                        1
# dtype: int64

# %%
plot.pie(why_sleep_group, labels=why_sleep_group.index, autopct='%1.1f%%')
plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
quality_group = filtSleepDF.groupby("sleep_quality").size()
quality_group
# Out:
# sleep_quality
# Good        23
# Great        5
# Mediocre    12
# Poor         5
# dtype: int64

# %%
plot.pie(quality_group, labels=quality_group.index, autopct='%1.1f%%')
plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Questions about "How": hot_cold, noise_silence, sleep_variety

# %%
hot_cold_group = filtSleepDF.groupby("hot_cold").size()
hot_cold_group
# Out:
# hot_cold
# Cold    44
# Hot      1
# dtype: int64

# %%
plot.pie(hot_cold_group, labels=hot_cold_group.index, autopct='%1.1f%%')
plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
noise_silence_group = filtSleepDF.groupby("noise_silence").size()
noise_silence_group
# Out:
# noise_silence
# Noise      12
# Silence    33
# dtype: int64

# %%
plot.pie(noise_silence_group, labels=noise_silence_group.index, autopct='%1.1f%%')
plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
slp_var_gropup = filtSleepDF.groupby("sleep_variety").size()
slp_var_gropup
# Out:
# sleep_variety
# Heavy     10
# Light      9
# Medium    26
# dtype: int64

# %%
plot.pie(slp_var_gropup, labels=slp_var_gropup.index, autopct='%1.1f%%')
plot.show
